# %%
class latent_RNN(torch.nn.Module):
    def __init__(self, obs_dim, latent_dim):
        super().__init__()
        
        self.rnn = torch.nn.RNN(input_size = obs_dim, hidden_size = latent_dim)
        self.calc_xt = torch.nn.Linear(in_features = latent_dim, out_features = obs_dim)

    def forward(self, time_series, h0):
        z_t, h_n = self.rnn(time_series, h0) # Calculate the hidden states according to (*)
        
        x_t = torch.zeros(time_series.shape)
        for t in range(time_series.shape[0]):
            x_t[t,:] = self.calc_xt(z_t[t,:]) # Calculate the ouput according to (**)
        
        h = h_n # ???
        return x_t, h

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

# %% [markdown]
# # Task 1
#
# We define a recurrent neural network with the structure $$z_t = tanh(V z_{t-1} + U x_{t-1} + b) \tag{*}$$
# $$x_t = W z_t + c \tag{**}$$
# Graphically this network can be interpreted as follows:
# ![title](latent_RNN.jpg)

# %% [markdown]
# # Task 2
# We will now define and train this neural network to reproduce a sinusoidal signal.

# %%
target = torch.load('sinus.pt')

plt.figure(figsize = (8,5))
plt.title('The two componenents of the signal the RNN is supposed to reproduce')
plt.plot(target, marker = 'x', linestyle = ' ', label = ['$x^0_t$', '$x^1_t$'])
plt.xlabel('t')
plt.legend()
plt.show()

# %% [markdown]
# We will first define some neccessary variables

# %%
torch.autograd.set_detect_anomaly(True)

hidden_size = 10 # A first guess
epochs = 51

learning_rate = 0.001

seq_length = 40
seq_per_epoch = 1

data = torch.load('sinus.pt')
observation_size = data.shape[1]

# %% [markdown]
# Now to define and initialize the RNN:

# %%
class latent_RNN(torch.nn.Module):
    def __init__(self, obs_dim, latent_dim):
        super().__init__()
        
        self.latent_dim = latent_dim
        self.obs_dim = obs_dim
        
        self.UV = torch.nn.Linear(in_features = obs_dim + latent_dim, out_features = latent_dim) # see (*)
        self.tanh = torch.nn.Tanh()
        
        self.W = torch.nn.Linear(in_features = latent_dim, out_features = obs_dim) # see (**)
    
    def forward(self, inputs, h0):
        h_t = torch.zeros(inputs.shape[0] + 1, self.latent_dim)
        h_t[0,:] = h0
        
        for t in range(1,inputs.shape[0]):
            combine = torch.cat((h_t[t-1], inputs[t-1]))
            h_t[t] = self.tanh(self.UV(combine)) # apply (*)
        
        x_t = self.W(h_t[1:]) # apply (**)
            
        return x_t, h_t

# %%
model = latent_RNN(observation_size, hidden_size)

# %% [markdown]
# Define the optimizer and loss funtion for training

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0)
loss_function = torch.nn.MSELoss()

# %% [markdown]
# Train the network

# %%
def train():
    for i in range(epochs):
        h0 = torch.randn((1, hidden_size))
        x = data[:-1]  #x_0:T-1
        y = data[1:]   #x_1:T
        
        # TASK 4: Here you need to do the mini-batching
        
        optimizer.zero_grad()               
        output, _ = model(x, h0)
        epoch_loss = loss_function(output, y)
        epoch_loss.backward()
        optimizer.step()
        if i % 10 == 0:
            print("Epoch: {} loss {}".format(i, epoch_loss.item()))
            plt.plot(output.detach().numpy())
            plt.plot(y)
            plt.show()

train()
# Out:
# Epoch: 0 loss 0.43902701139450073
# Epoch: 10 loss 0.44688791036605835
# Epoch: 20 loss 0.426626980304718
# Epoch: 30 loss 0.4280630946159363
# Epoch: 40 loss 0.4059376120567322
# Epoch: 50 loss 0.4102555215358734

# %%
with torch.no_grad():
    h = torch.zeros((1, hidden_size))
    predictions = torch.zeros((6*data.shape[0], observation_size))
    input_ = data[0:1]
    for i in range(6*data.size(0)):
        pred, h = model(input_, h)
        input_ = pred
        predictions[i] = pred
    
    plt.plot(data[1:])
    plt.plot(predictions)
    plt.savefig('Predictions', dpi=500)
